# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
np.random.seed(0)
points = 500
X = np.linspace(-3,3,points)
y = np.sin(X) + np.random.uniform(-0.5,0.5,points)

plt.scatter(X,y)

# %%
model = Sequential()
model.add(Dense(50,activation='sigmoid',input_dim=1))
model.add(Dense(30,activation='sigmoid'))
model.add(Dense(1))

# %%
model.compile(loss='mse',optimizer=Adam(lr=0.01))
model.fit(X,y,epochs=50)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 2s 3ms/step - loss: 0.4583
# Epoch 2/50
# 500/500 [==============================] - 0s 52us/step - loss: 0.2388
# Epoch 3/50
# 500/500 [==============================] - 0s 66us/step - loss: 0.2630
# Epoch 4/50
# 500/500 [==============================] - 0s 58us/step - loss: 0.2258
# Epoch 5/50
# 500/500 [==============================] - 0s 60us/step - loss: 0.2281
# Epoch 6/50
# 500/500 [==============================] - 0s 68us/step - loss: 0.2257
# Epoch 7/50
# 500/500 [==============================] - 0s 74us/step - loss: 0.2185
# Epoch 8/50
# 500/500 [==============================] - 0s 58us/step - loss: 0.2209
# Epoch 9/50
# 500/500 [==============================] - 0s 60us/step - loss: 0.2055
# Epoch 10/50
# 500/500 [==============================] - 0s 60us/step - loss: 0.1913
# Epoch 11/50
# 500/500 [==============================] - 0s 52us/step - loss: 0.1914
# Epoch 12/50
# 500/500 [==============================] - 0s 54us/step - loss: 0.1783
# Epoch 13/50
# 500/500 [==============================] - 0s 64us/step - loss: 0.1689
# Epoch 14/50
# 500/500 [==============================] - 0s 56us/step - loss: 0.1583
# Epoch 15/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.1559
# Epoch 16/50
# 500/500 [==============================] - 0s 64us/step - loss: 0.1451
# Epoch 17/50
# 500/500 [==============================] - 0s 50us/step - loss: 0.1386
# Epoch 18/50
# 500/500 [==============================] - 0s 64us/step - loss: 0.1312
# Epoch 19/50
# 500/500 [==============================] - 0s 48us/step - loss: 0.1223
# Epoch 20/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1272
# Epoch 21/50
# 500/500 [==============================] - 0s 48us/step - loss: 0.1180
# Epoch 22/50
# 500/500 [==============================] - 0s 50us/step - loss: 0.1169
# Epoch 23/50
# 500/500 [==============================] - 0s 56us/step - loss: 0.1183
# Epoch 24/50
# 500/500 [==============================] - 0s 66us/step - loss: 0.1177
# Epoch 25/50
# 500/500 [==============================] - 0s 64us/step - loss: 0.1114
# Epoch 26/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1080
# Epoch 27/50
# 500/500 [==============================] - 0s 78us/step - loss: 0.1111
# Epoch 28/50
# 500/500 [==============================] - 0s 54us/step - loss: 0.1244
# Epoch 29/50
# 500/500 [==============================] - 0s 68us/step - loss: 0.1239
# Epoch 30/50
# 500/500 [==============================] - 0s 62us/step - loss: 0.1129
# Epoch 31/50
# 500/500 [==============================] - 0s 60us/step - loss: 0.1079
# Epoch 32/50
# 500/500 [==============================] - 0s 48us/step - loss: 0.1144
# Epoch 33/50
# 500/500 [==============================] - 0s 54us/step - loss: 0.1080
# Epoch 34/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1111
# Epoch 35/50
# 500/500 [==============================] - 0s 50us/step - loss: 0.1047
# Epoch 36/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.1088
# Epoch 37/50
# 500/500 [==============================] - 0s 56us/step - loss: 0.1068
# Epoch 38/50
# 500/500 [==============================] - 0s 62us/step - loss: 0.1056
# Epoch 39/50
# 500/500 [==============================] - 0s 54us/step - loss: 0.1051
# Epoch 40/50
# 500/500 [==============================] - 0s 52us/step - loss: 0.1047
# Epoch 41/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.1152
# Epoch 42/50
# 500/500 [==============================] - 0s 58us/step - loss: 0.1031
# Epoch 43/50
# 500/500 [==============================] - 0s 48us/step - loss: 0.1033
# Epoch 44/50
# 500/500 [==============================] - 0s 68us/step - loss: 0.1059
# Epoch 45/50
# 500/500 [==============================] - 0s 68us/step - loss: 0.1020
# Epoch 46/50
# 500/500 [==============================] - 0s 82us/step - loss: 0.1018
# Epoch 47/50
# 500/500 [==============================] - 0s 69us/step - loss: 0.1123
# Epoch 48/50
# 500/500 [==============================] - 0s 52us/step - loss: 0.1087
# Epoch 49/50
# 500/500 [==============================] - 0s 76us/step - loss: 0.1042
# Epoch 50/50
# 500/500 [==============================] - 0s 84us/step - loss: 0.1079

# %%
predictions = model.predict(X)
plt.scatter(X,y)
plt.plot(X,predictions,'ro')
plt.show()
